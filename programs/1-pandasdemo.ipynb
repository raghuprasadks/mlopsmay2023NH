# %%
import pandas as pd

# %%
income=pd.read_csv('income.csv')

# %%
income
# Out:
#    Index                 State    Y2002    Y2003    Y2004    Y2005    Y2006  \
# 0      A               Alabama  1296530  1317711  1118631  1492583  1107408
# 1      A                Alaska  1170302  1960378  1818085  1447852  1861639
# 2      A               Arizona  1742027  1968140  1377583  1782199  1102568
# 3      A              Arkansas  1485531  1994927  1119299  1947979  1669191
# 4      C            California  1685349  1675807  1889570  1480280  1735069
# 5      C              Colorado  1343824  1878473  1886149  1236697  1871471
# 6      C           Connecticut  1610512  1232844  1181949  1518933  1841266
# 7      D              Delaware  1330403  1268673  1706751  1403759  1441351
# 8      D  District of Columbia  1111437  1993741  1374643  1827949  1803852
# 9      F               Florida  1964626  1468852  1419738  1362787  1339608
# 10     G               Georgia  1929009  1541565  1810773  1779091  1326846
# ...

# %%
print('data type of income')
print(type(income))
# Out:
# data type of income
# <class 'pandas.core.frame.DataFrame'>

# %%
df = pd.DataFrame(
{"a" : [4, 5, 6],
"b" : [7, 8, 9],
"c" : [10, 11, 12]},
index = [1, 2, 3])

# %%
df
# Out:
#    a  b   c
# 1  4  7  10
# 2  5  8  11
# 3  6  9  12

# %%
df = pd.DataFrame(
{"a" : [4, 5, 6],
"b" : [7, 8, 9],
"c" : [10, 11, 12]}
)

# %%
df
# Out:
#    a  b   c
# 0  4  7  10
# 1  5  8  11
# 2  6  9  12

# %%
print('columns of the dataset')
income.columns
# Out:
# columns of the dataset
# Index(['Index', 'State', 'Y2002', 'Y2003', 'Y2004', 'Y2005', 'Y2006', 'Y2007',
#        'Y2008', 'Y2009', 'Y2010', 'Y2011', 'Y2012', 'Y2013', 'Y2014', 'Y2015'],
#       dtype='object')

# %%
print('first five records')
income.head()
# Out:
# first five records
#   Index       State    Y2002    Y2003    Y2004    Y2005    Y2006    Y2007  \
# 0     A     Alabama  1296530  1317711  1118631  1492583  1107408  1440134
# 1     A      Alaska  1170302  1960378  1818085  1447852  1861639  1465841
# 2     A     Arizona  1742027  1968140  1377583  1782199  1102568  1109382
# 3     A    Arkansas  1485531  1994927  1119299  1947979  1669191  1801213
# 4     C  California  1685349  1675807  1889570  1480280  1735069  1812546
#
#      Y2008    Y2009    Y2010    Y2011    Y2012    Y2013    Y2014    Y2015
# 0  1945229  1944173  1237582  1440756  1186741  1852841  1558906  1916661
# 1  1551826  1436541  1629616  1230866  1512804  1985302  1580394  1979143
# 2  1752886  1554330  1300521  1130709  1907284  1363279  1525866  1647724
# 3  1188104  1628980  1669295  1928238  1216675  1591896  1360959  1329341
# 4  1487315  1663809  1624509  1639670  1921845  1156536  1388461  1644607

# %%
print('last five records')
income.tail()
# Out:
# last five records
#    Index          State    Y2002    Y2003    Y2004    Y2005    Y2006    Y2007  \
# 46     V       Virginia  1134317  1163996  1891068  1853855  1708715  1197698
# 47     W     Washington  1977749  1687136  1199490  1163092  1334864  1621989
# 48     W  West Virginia  1677347  1380662  1176100  1888948  1922085  1740826
# 49     W      Wisconsin  1788920  1518578  1289663  1436888  1251678  1721874
# 50     W        Wyoming  1775190  1498098  1198212  1881688  1750527  1523124
#
#       Y2008    Y2009    Y2010    Y2011    Y2012    Y2013    Y2014    Y2015
# 46  1803330  1590043  1516758  1171686  1262342  1647032  1706707  1850394
# 47  1545621  1555554  1179331  1150089  1775787  1273834  1387428  1377341
# 48  1238174  1539322  1539603  1872519  1462137  1683127  1204344  1198791
# 49  1980167  1901394  1648755  1940943  1729177  1510119  1701650  1846238
# 50  1587602  1504455  1282142  1881814  1673668  1994022  1204029  1853858

# %%
print('display random 10 records')
income.sample(n=10)
# Out:
# display random 10 records
#    Index           State    Y2002    Y2003    Y2004    Y2005    Y2006  \
# 12     I           Idaho  1353210  1438538  1739154  1541015  1122387
# 35     O            Ohio  1802132  1648498  1441386  1670280  1534888
# 38     P    Pennsylvania  1320191  1446723  1218591  1122030  1971479
# 40     S  South Carolina  1631522  1803455  1425193  1458191  1538731
# 47     W      Washington  1977749  1687136  1199490  1163092  1334864
# 37     O          Oregon  1794912  1726665  1805445  1133510  1502242
# 11     H          Hawaii  1461570  1200280  1213993  1245931  1459383
# 15     I            Iowa  1499269  1444576  1576367  1388924  1554813
# 48     W   West Virginia  1677347  1380662  1176100  1888948  1922085
# 49     W       Wisconsin  1788920  1518578  1289663  1436888  1251678
#
#       Y2007    Y2008    Y2009    Y2010    Y2011    Y2012    Y2013    Y2014  \
# 12  1772050  1335481  1748608  1436809  1456340  1643855  1312561  1713718
# ...

# %%
print('display random 20 percent of records')
income.sample(frac=.20)
# Out:
# display random 20 percent of records
#    Index           State    Y2002    Y2003    Y2004    Y2005    Y2006  \
# 35     O            Ohio  1802132  1648498  1441386  1670280  1534888
# 16     K          Kansas  1509054  1290700  1522230  1532094  1104256
# 28     N          Nevada  1426117  1114500  1119707  1758830  1694526
# 33     N  North Carolina  1616742  1292223  1482792  1532347  1158716
# 40     S  South Carolina  1631522  1803455  1425193  1458191  1538731
# 19     M           Maine  1582720  1678622  1208496  1912040  1438549
# 23     M       Minnesota  1729921  1675204  1903907  1561839  1985692
# 31     N      New Mexico  1819239  1226057  1935991  1124400  1723493
# 47     W      Washington  1977749  1687136  1199490  1163092  1334864
# 29     N   New Hampshire  1419776  1854370  1195119  1990062  1645430
#
#       Y2007    Y2008    Y2009    Y2010    Y2011    Y2012    Y2013    Y2014  \
# 35  1314824  1516621  1511460  1585465  1887714  1227303  1840898  1880804
# ...

# %%
income.dtypes
# Out:
# Index    object
# State    object
# Y2002     int64
# Y2003     int64
# Y2004     int64
# Y2005     int64
# Y2006     int64
# Y2007     int64
# Y2008     int64
# Y2009     int64
# Y2010     int64
# Y2011     int64
# Y2012     int64
# Y2013     int64
# Y2014     int64
# Y2015     int64
# dtype: object

# %%
print('data size')
income.shape
# Out:
# data size
# (51, 16)

# %%
income.State
# Out:
# 0                  Alabama
# 1                   Alaska
# 2                  Arizona
# 3                 Arkansas
# 4               California
# 5                 Colorado
# 6              Connecticut
# 7                 Delaware
# 8     District of Columbia
# 9                  Florida
# 10                 Georgia
# 11                  Hawaii
# 12                   Idaho
# 13                Illinois
# 14                 Indiana
# 15                    Iowa
# 16                  Kansas
# 17                Kentucky
# 18               Louisiana
# 19                   Maine
# 20                Maryland
# 21           Massachusetts
# 22                Michigan
# 23               Minnesota
# 24             Mississippi
# 25                Missouri
# 26                 Montana
# 27                Nebraska
# 28                  Nevada
# 29           New Hampshire
# 30              New Jersey
# 31              New Mexico
# 32                New York
# 33          North Carolina
# ...

# %%
income['State']
# Out:
# 0                  Alabama
# 1                   Alaska
# 2                  Arizona
# 3                 Arkansas
# 4               California
# 5                 Colorado
# 6              Connecticut
# 7                 Delaware
# 8     District of Columbia
# 9                  Florida
# 10                 Georgia
# 11                  Hawaii
# 12                   Idaho
# 13                Illinois
# 14                 Indiana
# 15                    Iowa
# 16                  Kansas
# 17                Kentucky
# 18               Louisiana
# 19                   Maine
# 20                Maryland
# 21           Massachusetts
# 22                Michigan
# 23               Minnesota
# 24             Mississippi
# 25                Missouri
# 26                 Montana
# 27                Nebraska
# 28                  Nevada
# 29           New Hampshire
# 30              New Jersey
# 31              New Mexico
# 32                New York
# 33          North Carolina
# ...

# %%
print('display first two records')
income.iloc[:2]
# Out:
# display first two records
#   Index    State    Y2002    Y2003    Y2004    Y2005    Y2006    Y2007  \
# 0     A  Alabama  1296530  1317711  1118631  1492583  1107408  1440134
# 1     A   Alaska  1170302  1960378  1818085  1447852  1861639  1465841
#
#      Y2008    Y2009    Y2010    Y2011    Y2012    Y2013    Y2014    Y2015
# 0  1945229  1944173  1237582  1440756  1186741  1852841  1558906  1916661
# 1  1551826  1436541  1629616  1230866  1512804  1985302  1580394  1979143

# %%
print('diplay first two columns data')
income.iloc[:,:2]
# Out:
# diplay first two columns data
#    Index                 State
# 0      A               Alabama
# 1      A                Alaska
# 2      A               Arizona
# 3      A              Arkansas
# 4      C            California
# 5      C              Colorado
# 6      C           Connecticut
# 7      D              Delaware
# 8      D  District of Columbia
# 9      F               Florida
# 10     G               Georgia
# 11     H                Hawaii
# 12     I                 Idaho
# 13     I              Illinois
# 14     I               Indiana
# 15     I                  Iowa
# 16     K                Kansas
# 17     K              Kentucky
# 18     L             Louisiana
# 19     M                 Maine
# 20     M              Maryland
# 21     M         Massachusetts
# 22     M              Michigan
# 23     M             Minnesota
# 24     M           Mississippi
# 25     M              Missouri
# 26     M               Montana
# 27     N              Nebraska
# ...

# %%
print('display data of the specific columns')
income.loc[:,["State","Y2003"]]
# Out:
# display data of the specific columns
#                    State    Y2003
# 0                Alabama  1317711
# 1                 Alaska  1960378
# 2                Arizona  1968140
# 3               Arkansas  1994927
# 4             California  1675807
# 5               Colorado  1878473
# 6            Connecticut  1232844
# 7               Delaware  1268673
# 8   District of Columbia  1993741
# 9                Florida  1468852
# 10               Georgia  1541565
# 11                Hawaii  1200280
# 12                 Idaho  1438538
# 13              Illinois  1527440
# 14               Indiana  1734104
# 15                  Iowa  1444576
# 16                Kansas  1290700
# 17              Kentucky  1448846
# 18             Louisiana  1110625
# 19                 Maine  1678622
# 20              Maryland  1404700
# 21         Massachusetts  1686259
# 22              Michigan  1149931
# 23             Minnesota  1675204
# 24           Mississippi  1292558
# ...

# %%
print('series ')
s = pd.Series([1,2,3,1,2])
print(s)
# Out:
# series
# 0    1
# 1    2
# 2    3
# 3    1
# 4    2
# dtype: int64
