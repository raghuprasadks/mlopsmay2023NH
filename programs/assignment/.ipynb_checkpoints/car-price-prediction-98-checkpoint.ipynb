# %% [markdown]
# ### You can contact me by email : mahsaghonchehei18@gmail.com

# %%
#import libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
#read data set

data = pd.read_csv("car data.csv")
data
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# 2        Dealer       Manual      0
# 3        Dealer       Manual      0
# 4        Dealer       Manual      0
# ..          ...          ...    ...
# 296      Dealer       Manual      0
# 297      Dealer       Manual      0
# 298      Dealer       Manual      0
# 299      Dealer       Manual      0
# 300      Dealer       Manual      0
#
# [301 rows x 9 columns]

# %%
# checkimg data

data.head(20)
# Out:
#          Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0            ritz  2014           3.35           5.59       27000    Petrol
# 1             sx4  2013           4.75           9.54       43000    Diesel
# 2            ciaz  2017           7.25           9.85        6900    Petrol
# 3         wagon r  2011           2.85           4.15        5200    Petrol
# 4           swift  2014           4.60           6.87       42450    Diesel
# 5   vitara brezza  2018           9.25           9.83        2071    Diesel
# 6            ciaz  2015           6.75           8.12       18796    Petrol
# 7         s cross  2015           6.50           8.61       33429    Diesel
# 8            ciaz  2016           8.75           8.89       20273    Diesel
# 9            ciaz  2015           7.45           8.92       42367    Diesel
# 10       alto 800  2017           2.85           3.60        2135    Petrol
# 11           ciaz  2015           6.85          10.38       51000    Diesel
# 12           ciaz  2015           7.50           9.94       15000    Petrol
# 13         ertiga  2015           6.10           7.71       26000    Petrol
# 14          dzire  2009           2.25           7.21       77427    Petrol
# 15         ertiga  2016           7.75          10.79       43000    Diesel
# 16         ertiga  2015           7.25          10.79       41678    Diesel
# 17         ertiga  2016           7.75          10.79       43000    Diesel
# 18        wagon r  2015           3.25           5.09       35500       CNG
# 19            sx4  2010           2.65           7.98       41442    Petrol
#
#    Seller_Type Transmission  Owner
# 0       Dealer       Manual      0
# 1       Dealer       Manual      0
# 2       Dealer       Manual      0
# 3       Dealer       Manual      0
# 4       Dealer       Manual      0
# 5       Dealer       Manual      0
# 6       Dealer       Manual      0
# 7       Dealer       Manual      0
# 8       Dealer       Manual      0
# 9       Dealer       Manual      0
# 10      Dealer       Manual      0
# 11      Dealer       Manual      0
# 12      Dealer    Automatic      0
# 13      Dealer       Manual      0
# 14      Dealer       Manual      0
# 15      Dealer       Manual      0
# 16      Dealer       Manual      0
# 17      Dealer       Manual      0
# 18      Dealer       Manual      0
# 19      Dealer       Manual      0

# %%
# data shape

data.shape
# Out:
# (301, 9)

# %%
#Showing data columns Data Type

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    object
#  1   Year           301 non-null    int64
#  2   Selling_Price  301 non-null    float64
#  3   Present_Price  301 non-null    float64
#  4   Kms_Driven     301 non-null    int64
#  5   Fuel_Type      301 non-null    object
#  6   Seller_Type    301 non-null    object
#  7   Transmission   301 non-null    object
#  8   Owner          301 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 21.3+ KB

# %%
# Show the sum of the null values in every columns in data

data.isnull().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Kms_Driven       0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# Owner            0
# dtype: int64

# %%
#showing some details about data

data.describe()
# Out:
#               Year  Selling_Price  Present_Price     Kms_Driven       Owner
# count   301.000000     301.000000     301.000000     301.000000  301.000000
# mean   2013.627907       4.661296       7.628472   36947.205980    0.043189
# std       2.891554       5.082812       8.644115   38886.883882    0.247915
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.900000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.600000       6.400000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.900000   48767.000000    0.000000
# max    2018.000000      35.000000      92.600000  500000.000000    3.000000

# %% [markdown]
# #

# %% [markdown]
# # Age

# %%
# find the maximum Year in data set

np.max(data.Year)
# Out:
# 2018

# %%
# convert Year to Age of each cars

Age = 2019 - data.Year

data.insert(0, "Age", Age)
data.drop('Year', axis = 1, inplace = True)
data
# Out:
#      Age Car_Name  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0      5     ritz           3.35           5.59       27000    Petrol
# 1      6      sx4           4.75           9.54       43000    Diesel
# 2      2     ciaz           7.25           9.85        6900    Petrol
# 3      8  wagon r           2.85           4.15        5200    Petrol
# 4      5    swift           4.60           6.87       42450    Diesel
# ..   ...      ...            ...            ...         ...       ...
# 296    3     city           9.50          11.60       33988    Diesel
# 297    4     brio           4.00           5.90       60000    Petrol
# 298   10     city           3.35          11.00       87934    Petrol
# 299    2     city          11.50          12.50        9000    Diesel
# 300    3     brio           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# 2        Dealer       Manual      0
# 3        Dealer       Manual      0
# 4        Dealer       Manual      0
# ..          ...          ...    ...
# 296      Dealer       Manual      0
# 297      Dealer       Manual      0
# 298      Dealer       Manual      0
# 299      Dealer       Manual      0
# 300      Dealer       Manual      0
#
# [301 rows x 9 columns]

# %% [markdown]
# #

# %%
# showing data correlation

data.corr()
# Out:
#                     Age  Selling_Price  Present_Price  Kms_Driven     Owner
# Age            1.000000      -0.236141       0.047584    0.524342  0.182104
# Selling_Price -0.236141       1.000000       0.878983    0.029187 -0.088344
# Present_Price  0.047584       0.878983       1.000000    0.203647  0.008057
# Kms_Driven     0.524342       0.029187       0.203647    1.000000  0.089216
# Owner          0.182104      -0.088344       0.008057    0.089216  1.000000

# %%
# draw Heat Map 

plt.figure(figsize=(15, 10))
sns.heatmap(data.corr(), annot=True)
plt.title('Heat Map', size=20)
plt.yticks(rotation = 0)
plt.show()

# %% [markdown]
# #

# %% [markdown]
# # Plots

# %%
# Draw distribution diagram for Selling Price

sns.set_style("whitegrid")
plt.figure(figsize=(15, 10))
sns.distplot(data.Selling_Price)
plt.title('Car Price Distribution Plot')
plt.show()

# %%
# make function for count plot and scatter plots for Categorical features

def Categorical_Plot(column):
    
        plt.figure(figsize=(20, 5))
        plt.subplot(1,2,1)
        pd.value_counts(data[column]).plot(kind='bar')
        plt.xticks( horizontalalignment="center", fontsize=15)
        plt.xlabel(f"\n{str(column)}", fontsize=15)
        plt.ylabel("Count\n", fontsize=15)
        plt.yticks(fontsize = 15)
        plt.title(f"{str(column)} - Count\n", fontsize = 15)

        plt.subplot(1, 2,2)
        plt.scatter(data[column], data.Selling_Price)
        plt.xticks( horizontalalignment="center", fontsize=15)
        plt.xlabel(f"\n{str(column)}", fontsize=15)
        plt.yticks(fontsize = 15)
        plt.title(f"{str(column)} - Selling_Price\n", fontsize = 15)
        plt.ylabel("Selling_Price\n", fontsize=15)

        plt.show()
        print()

# %%
# call Categorical_Plot fuction for Fuel_Type

Categorical_Plot("Fuel_Type")

# %%
# call Categorical_Plot fuction for Seller_Type

Categorical_Plot("Seller_Type")

# %%
# call Categorical_Plot fuction for Transmission

Categorical_Plot("Transmission")

# %%
# call Categorical_Plot fuction for Owner

Categorical_Plot("Owner")

# %%
# make function for box plots and scatter plots for Numerical features

def Numerical_Plot(column):
    
        plt.figure(figsize=(20, 5))
        plt.subplot(1,2,1)
        sns.boxplot(data[column])
        plt.xticks( horizontalalignment="center", fontsize=15)
        plt.xlabel(f"\n{str(column)}", fontsize=15)
        plt.yticks(fontsize = 15)
        plt.title(f"\n{str(column)} Box Plot\n", fontsize = 15)

        plt.subplot(1, 2,2)
        plt.scatter(data[column], data.Selling_Price)
        plt.xticks( horizontalalignment="center", fontsize=15)
        plt.xlabel(f"\n{str(column)}", fontsize=15)
        plt.yticks(fontsize = 15)
        plt.title(f"{str(column)} - Selling_Price\n", fontsize = 15)
        plt.ylabel("Selling_Price\n", fontsize=15)

        plt.show()
        print()

# %%
# call Numerical_Plot fuction for Age

Numerical_Plot("Age")

# %%
# call Numerical_Plot fuction for Present_Price

Numerical_Plot("Present_Price")

# %%
# call Numerical_Plot fuction for Kms_Driven

Numerical_Plot("Kms_Driven")

# %%
plt.figure(figsize=(25, 5))
sns.pairplot(data)
plt.show()

# %% [markdown]
# #

# %% [markdown]
# ## Changing categorical features to numerical

# %%
# showing feature values

print("Fuel Type    = ", data.Fuel_Type.unique(),"\n")
print("Seller Type  = ", data.Seller_Type.unique(), "\n")
print("Transmission = ", data.Transmission.unique(), "\n")
print("Owner        = ", data.Owner.unique(), "\n")
# Out:
# Fuel Type    =  ['Petrol' 'Diesel' 'CNG']
#
# Seller Type  =  ['Dealer' 'Individual']
#
# Transmission =  ['Manual' 'Automatic']
#
# Owner        =  [0 1 3]

# %%
# showing the count of Fuel_Type values

data.Fuel_Type.value_counts()
# Out:
# Petrol    239
# Diesel     60
# CNG         2
# Name: Fuel_Type, dtype: int64

# %%
# showing the count of Seller_Type values

data.Seller_Type.value_counts()
# Out:
# Dealer        195
# Individual    106
# Name: Seller_Type, dtype: int64

# %%
# showing the count of Transmission values

data.Transmission.value_counts()
# Out:
# Manual       261
# Automatic     40
# Name: Transmission, dtype: int64

# %%
# showing the count of Owner values

data.Owner.value_counts()
# Out:
# 0    290
# 1     10
# 3      1
# Name: Owner, dtype: int64

# %%
# changing categorical features to numerical

data["Fuel_Type"].replace({'Petrol':2, 'Diesel':3, 'CNG':4},inplace = True)
data["Seller_Type"].replace({'Dealer':2, 'Individual':3}, inplace = True)
data["Transmission"].replace({'Manual':2, 'Automatic':3}, inplace = True)
data.drop("Car_Name", axis=1, inplace = True)

data
# Out:
#      Age  Selling_Price  Present_Price  Kms_Driven  Fuel_Type  Seller_Type  \
# 0      5           3.35           5.59       27000          2            2
# 1      6           4.75           9.54       43000          3            2
# 2      2           7.25           9.85        6900          2            2
# 3      8           2.85           4.15        5200          2            2
# 4      5           4.60           6.87       42450          3            2
# ..   ...            ...            ...         ...        ...          ...
# 296    3           9.50          11.60       33988          3            2
# 297    4           4.00           5.90       60000          2            2
# 298   10           3.35          11.00       87934          2            2
# 299    2          11.50          12.50        9000          3            2
# 300    3           5.30           5.90        5464          2            2
#
#      Transmission  Owner
# 0               2      0
# 1               2      0
# 2               2      0
# 3               2      0
# 4               2      0
# ..            ...    ...
# 296             2      0
# 297             2      0
# 298             2      0
# 299             2      0
# 300             2      0
#
# [301 rows x 8 columns]

# %%
# cheking the features changes

print("Fuel Type    = ", pd.unique(data["Fuel_Type"]))
print("Seller Type  = ", pd.unique(data["Seller_Type"]))
print("Transmission = ", pd.unique(data["Transmission"]))
print("Owner        = ", pd.unique(data["Owner"]))
# Out:
# Fuel Type    =  [2 3 4]
# Seller Type  =  [2 3]
# Transmission =  [2 3]
# Owner        =  [0 1 3]

# %%
#Showing data columns Data Type

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Age            301 non-null    int64
#  1   Selling_Price  301 non-null    float64
#  2   Present_Price  301 non-null    float64
#  3   Kms_Driven     301 non-null    int64
#  4   Fuel_Type      301 non-null    int64
#  5   Seller_Type    301 non-null    int64
#  6   Transmission   301 non-null    int64
#  7   Owner          301 non-null    int64
# dtypes: float64(2), int64(6)
# memory usage: 18.9 KB

# %%
data.describe(include = 'all')
# Out:
#               Age  Selling_Price  Present_Price     Kms_Driven   Fuel_Type  \
# count  301.000000     301.000000     301.000000     301.000000  301.000000
# mean     5.372093       4.661296       7.628472   36947.205980    2.212625
# std      2.891554       5.082812       8.644115   38886.883882    0.425801
# min      1.000000       0.100000       0.320000     500.000000    2.000000
# 25%      3.000000       0.900000       1.200000   15000.000000    2.000000
# 50%      5.000000       3.600000       6.400000   32000.000000    2.000000
# 75%      7.000000       6.000000       9.900000   48767.000000    2.000000
# max     16.000000      35.000000      92.600000  500000.000000    4.000000
#
#        Seller_Type  Transmission       Owner
# count   301.000000    301.000000  301.000000
# mean      2.352159      2.132890    0.043189
# std       0.478439      0.340021    0.247915
# min       2.000000      2.000000    0.000000
# 25%       2.000000      2.000000    0.000000
# 50%       2.000000      2.000000    0.000000
# 75%       3.000000      2.000000    0.000000
# max       3.000000      3.000000    3.000000

# %%
# Heat Map for correlation

plt.figure(figsize=(15, 10))
sns.heatmap(data.corr(), annot=True)
plt.yticks(rotation = 0)
plt.title('Heat Map', size=20)
plt.show()

# %% [markdown]
# #

# %% [markdown]
# # Modeling

# %%
x = pd.DataFrame(data, columns = ['Age','Present_Price', 'Kms_Driven', 'Fuel_Type', 'Seller_Type', 'Transmission', 'Owner'])
y = data['Selling_Price'].values.reshape(-1, 1)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(x, y, test_size = 0.2, random_state = 0)
model = LinearRegression()
model.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
Y_pred = model.predict(X_test)

# %%
model.intercept_
# Out:
# array([-0.0124171])

# %%
model.coef_
# Out:
# array([[-3.92595063e-01,  4.36619980e-01, -5.48584299e-06,
#          1.44377315e+00, -1.12076998e+00,  1.43830531e+00,
#         -9.89222658e-01]])

# %%
# Evalutions

# MAE
print("Mean Absolute Error     : ", metrics.mean_absolute_error(Y_test, Y_pred))

# MSE
print("Mean Squared Error      : ", metrics.mean_squared_error(Y_test, Y_pred))

# RMSE
print("Root Mean Squared Error : ", np.sqrt(metrics.mean_squared_error(Y_test, Y_pred)))

#R2 Score
print("R2 Score                : ", metrics.r2_score(Y_test, Y_pred))
# Out:
# Mean Absolute Error     :  1.0000326012146703
# Mean Squared Error      :  2.1885564456573303
# Root Mean Squared Error :  1.4793770464818394
# R2 Score                :  0.9134181721224648

# %% [markdown]
# ## R2 Score  = 0.9134181721224179

# %% [markdown]
# #

# %% [markdown]
# # Improving Model

# %%
x1 = x.copy()

# make a function for features dimenation

def Dimenations(column, dimenation):
    
    new_column = x1[column]**dimenation
    x1.insert(0, str(column)+ str(dimenation), new_column)


# make a function for Train model and show New R2 Score

def Training_R2():
    
    X_train2, X_test2, Y_train2, Y_test2 = train_test_split(x1, y, test_size = 0.2, random_state = 0)
    model2 = LinearRegression()
    model2.fit(X_train2, Y_train2)
    Y_pred2 = model2.predict(X_test2)
    
    print("NEW R2 Score : ", metrics.r2_score(Y_test2, Y_pred2))

# %%
Dimenations("Present_Price", 2)
Training_R2()
# Out:
# NEW R2 Score :  0.9198798658487896

# %%
Dimenations("Kms_Driven", 2)
Training_R2()
# Out:
# NEW R2 Score :  0.9279862424439957

# %%
Dimenations("Fuel_Type", 2)
Training_R2()
# Out:
# NEW R2 Score :  0.9285797570184752

# %%
Dimenations("Owner", 2)
Training_R2()
# Out:
# NEW R2 Score :  0.9311515326443397

# %%
x = x1
x
# Out:
#      Owner2  Fuel_Type2  Kms_Driven2  Present_Price2  Age  Present_Price  \
# 0         0           4    729000000         31.2481    5           5.59
# 1         0           9   1849000000         91.0116    6           9.54
# 2         0           4     47610000         97.0225    2           9.85
# 3         0           4     27040000         17.2225    8           4.15
# 4         0           9   1802002500         47.1969    5           6.87
# ..      ...         ...          ...             ...  ...            ...
# 296       0           9   1155184144        134.5600    3          11.60
# 297       0           4   3600000000         34.8100    4           5.90
# 298       0           4   7732388356        121.0000   10          11.00
# 299       0           9     81000000        156.2500    2          12.50
# 300       0           4     29855296         34.8100    3           5.90
#
#      Kms_Driven  Fuel_Type  Seller_Type  Transmission  Owner
# 0         27000          2            2             2      0
# 1         43000          3            2             2      0
# 2          6900          2            2             2      0
# 3          5200          2            2             2      0
# 4         42450          3            2             2      0
# ..          ...        ...          ...           ...    ...
# 296       33988          3            2             2      0
# 297       60000          2            2             2      0
# 298       87934          2            2             2      0
# 299        9000          3            2             2      0
# 300        5464          2            2             2      0
#
# [301 rows x 11 columns]

# %% [markdown]
# ## R2 Score =  0.9311515303255717

# %% [markdown]
# #

# %%
x1.insert(0, "PressPrice_Kms", x1.Present_Price * x1.Kms_Driven)
Training_R2()
# Out:
# NEW R2 Score :  0.9503856427868844

# %%
x1.insert(0, "PressPrice_Kms2", x.Present_Price * x1.Kms_Driven2)
Training_R2()
# Out:
# NEW R2 Score :  0.9582517324308761

# %%
x1.insert(0, "PressPrice2_Kms", x1.Present_Price2 * x1.Kms_Driven)
Training_R2()
# Out:
# NEW R2 Score :  0.9562007290546672

# %%
x1.insert(0, "PressPrice2_Kms2", x1.Present_Price2 * x1.Kms_Driven2)
Training_R2()
# Out:
# NEW R2 Score :  0.9592459937555632

# %%
x1.insert(0, "PressPrice_Fuel", x1.Present_Price * x1.Fuel_Type)
Training_R2()
# Out:
# NEW R2 Score :  0.9615642486518027

# %%
x1.insert(0, "PressPrice_Fuel2", x1.Present_Price * x1.Fuel_Type2)
Training_R2()
# Out:
# NEW R2 Score :  0.9612905314283059

# %%
x = x1
x
# Out:
#      PressPrice_Fuel2  PressPrice_Fuel  PressPrice2_Kms2  PressPrice2_Kms  \
# 0               22.36            11.18      2.277986e+10     8.436987e+05
# 1               85.86            28.62      1.682804e+11     3.913499e+06
# 2               39.40            19.70      4.619241e+09     6.694552e+05
# 3               16.60             8.30      4.656964e+08     8.955700e+04
# 4               61.83            20.61      8.504893e+10     2.003508e+06
# ..                ...              ...               ...              ...
# 296            104.40            34.80      1.554416e+11     4.573425e+06
# 297             23.60            11.80      1.253160e+11     2.088600e+06
# 298             44.00            22.00      9.356190e+11     1.064001e+07
# 299            112.50            37.50      1.265625e+10     1.406250e+06
# 300             23.60            11.80      1.039263e+09     1.902018e+05
#
#      PressPrice_Kms2  PressPrice_Kms  Owner2  Fuel_Type2  Kms_Driven2  \
# 0       4.075110e+09        150930.0       0           4    729000000
# 1       1.763946e+10        410220.0       0           9   1849000000
# 2       4.689585e+08         67965.0       0           4     47610000
# 3       1.122160e+08         21580.0       0           4     27040000
# 4       1.237976e+10        291631.5       0           9   1802002500
# ..               ...             ...     ...         ...          ...
# 296     1.340014e+10        394260.8       0           9   1155184144
# 297     2.124000e+10        354000.0       0           4   3600000000
# 298     8.505627e+10        967274.0       0           4   7732388356
# 299     1.012500e+09        112500.0       0           9     81000000
# 300     1.761462e+08         32237.6       0           4     29855296
#
#      Present_Price2  Age  Present_Price  Kms_Driven  Fuel_Type  Seller_Type  \
# 0           31.2481    5           5.59       27000          2            2
# 1           91.0116    6           9.54       43000          3            2
# 2           97.0225    2           9.85        6900          2            2
# 3           17.2225    8           4.15        5200          2            2
# 4           47.1969    5           6.87       42450          3            2
# ..              ...  ...            ...         ...        ...          ...
# 296        134.5600    3          11.60       33988          3            2
# 297         34.8100    4           5.90       60000          2            2
# 298        121.0000   10          11.00       87934          2            2
# 299        156.2500    2          12.50        9000          3            2
# 300         34.8100    3           5.90        5464          2            2
#
#      Transmission  Owner
# 0               2      0
# 1               2      0
# 2               2      0
# 3               2      0
# 4               2      0
# ..            ...    ...
# 296             2      0
# 297             2      0
# 298             2      0
# 299             2      0
# 300             2      0
#
# [301 rows x 17 columns]

# %%
X_train, X_test, Y_train, Y_test = train_test_split(x, y, test_size = 0.2, random_state = 0)
model = LinearRegression()
model.fit(X_train, Y_train)
Y_pred = model.predict(X_test)


print("Mean Absolute Error     : ", metrics.mean_absolute_error(Y_test, Y_pred))
print("Mean Squared Error      : ", metrics.mean_squared_error(Y_test, Y_pred))
print("Root Mean Squared Error : ", np.sqrt(metrics.mean_squared_error(Y_test, Y_pred)))
print("R2 Score                : ", metrics.r2_score(Y_test, Y_pred))
# Out:
# Mean Absolute Error     :  0.6694306164533436
# Mean Squared Error      :  0.9784715687728313
# Root Mean Squared Error :  0.9891772180821955
# R2 Score                :  0.9612905314283059

# %% [markdown]
# ## R2 Score = 0.9612748373179915

# %% [markdown]
# #

# %%
#croos validatin

results = cross_val_score(model, x, y, cv=KFold(5))

print(results)    
print()
print(np.mean(results))
# Out:
# [  0.92316359   0.17855775 -24.17550592   0.54876346   0.88506708]
#
# -4.327990809204648

# %%
# R2 Score

result = model.score(X_test,Y_test)
result
# Out:
# 0.9612905314283059

# %%
x.shape
# Out:
# (301, 17)

# %%
print("Low  = ", 301/6 *2)
print("High = ", 301/6 *3)
# Out:
# Low  =  100.33333333333333
# High =  150.5

# %%
# remove the indexs by negative Scores

x1 = x[x.index<100]
x2 = x[x.index>151]
x_new = x1.append(x2)
x_new.reset_index(drop=True, inplace=True)
x_new
# Out:
#      PressPrice_Fuel2  PressPrice_Fuel  PressPrice2_Kms2  PressPrice2_Kms  \
# 0               22.36            11.18      2.277986e+10     8.436987e+05
# 1               85.86            28.62      1.682804e+11     3.913499e+06
# 2               39.40            19.70      4.619241e+09     6.694552e+05
# 3               16.60             8.30      4.656964e+08     8.955700e+04
# 4               61.83            20.61      8.504893e+10     2.003508e+06
# ..                ...              ...               ...              ...
# 244            104.40            34.80      1.554416e+11     4.573425e+06
# 245             23.60            11.80      1.253160e+11     2.088600e+06
# 246             44.00            22.00      9.356190e+11     1.064001e+07
# 247            112.50            37.50      1.265625e+10     1.406250e+06
# 248             23.60            11.80      1.039263e+09     1.902018e+05
#
#      PressPrice_Kms2  PressPrice_Kms  Owner2  Fuel_Type2  Kms_Driven2  \
# 0       4.075110e+09        150930.0       0           4    729000000
# 1       1.763946e+10        410220.0       0           9   1849000000
# 2       4.689585e+08         67965.0       0           4     47610000
# 3       1.122160e+08         21580.0       0           4     27040000
# 4       1.237976e+10        291631.5       0           9   1802002500
# ..               ...             ...     ...         ...          ...
# 244     1.340014e+10        394260.8       0           9   1155184144
# 245     2.124000e+10        354000.0       0           4   3600000000
# 246     8.505627e+10        967274.0       0           4   7732388356
# 247     1.012500e+09        112500.0       0           9     81000000
# 248     1.761462e+08         32237.6       0           4     29855296
#
#      Present_Price2  Age  Present_Price  Kms_Driven  Fuel_Type  Seller_Type  \
# 0           31.2481    5           5.59       27000          2            2
# 1           91.0116    6           9.54       43000          3            2
# 2           97.0225    2           9.85        6900          2            2
# 3           17.2225    8           4.15        5200          2            2
# 4           47.1969    5           6.87       42450          3            2
# ..              ...  ...            ...         ...        ...          ...
# 244        134.5600    3          11.60       33988          3            2
# 245         34.8100    4           5.90       60000          2            2
# 246        121.0000   10          11.00       87934          2            2
# 247        156.2500    2          12.50        9000          3            2
# 248         34.8100    3           5.90        5464          2            2
#
#      Transmission  Owner
# 0               2      0
# 1               2      0
# 2               2      0
# 3               2      0
# 4               2      0
# ..            ...    ...
# 244             2      0
# 245             2      0
# 246             2      0
# 247             2      0
# 248             2      0
#
# [249 rows x 17 columns]

# %%
# remove the indexs by negative Scores

y  = data["Selling_Price"]
y1 = y[y.index<100]
y2 = y[y.index>151]
y_new = y1.append(y2)
y_new.reset_index(drop=True, inplace=True)
y_new.shape
# Out:
# (249,)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(x_new, y_new, test_size = 0.2, random_state = 0)
model = LinearRegression()
model.fit(X_train, Y_train)
Y_pred = model.predict(X_test)

print("Mean Absolute Error     : ", metrics.mean_absolute_error(Y_test, Y_pred))
print("Mean Squared Error      : ", metrics.mean_squared_error(Y_test, Y_pred))
print("Root Mean Squared Error : ", np.sqrt(metrics.mean_squared_error(Y_test, Y_pred)))
print("R2 Score                : ", metrics.r2_score(Y_test, Y_pred))
# Out:
# Mean Absolute Error     :  0.6645969023941567
# Mean Squared Error      :  0.7289803785600868
# Root Mean Squared Error :  0.8538034777160882
# R2 Score                :  0.9801669548950894

# %%
model.intercept_
# Out:
# 9.972314012442276

# %%
model.coef_
# Out:
# array([-2.87828402e-01,  1.71552680e+00,  1.44551038e-12, -7.34421263e-08,
#         1.32263644e-11, -9.97166491e-06, -5.50932420e-01,  1.25360354e+00,
#        -7.20699670e-11, -4.46111361e-03, -2.96758851e-01, -1.34567057e+00,
#         4.01799003e-05, -7.73744998e+00, -1.02736584e-01,  7.20997971e-01,
#         9.24002832e-01])

# %% [markdown]
# ## R2 Score = 0.9801683909737401

# %% [markdown]
# #

# %% [markdown]
# # Plots

# %%
X_test.insert(0, "Y_test", Y_test)
X_test.insert(0, "Y_pred", Y_pred)

# %%
df = X_test.sort_values(by="Present_Price")

# %%
# checking the model by visualization

plt.figure(figsize=(20, 10))
plt.scatter(df.Present_Price ,df.Y_test, color='blue', label="Real")
plt.scatter(df.Present_Price, df.Y_pred, color='red', label="Prediction")
plt.legend(fontsize=30)
plt.show()

# %% [markdown]
# #

# %%
# checking the model by visualization

plt.figure(figsize=(20, 10))
plt.scatter(df.Present_Price , df.Y_test, color='blue', label="Real")
plt.plot(df.Present_Price, df.Y_pred, color='red', label="Prediction")
plt.legend(fontsize=30)
plt.show()

# %% [markdown]
# #

# %% [markdown]
# ### You can contact me by email : mahsaghonchehei18@gmail.com
